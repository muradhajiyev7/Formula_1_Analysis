# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("F1DriversDataset.csv")

# %% [markdown]
# # **Dataset**
# **Driver:** Name of the racing driver.
#
# **Nationality:** The country to which the driver belongs.
#
# **Seasons:** Number of seasons the driver has participated in.
#
# **Championships:** Total number of championships won by the driver.
#
# **Race_Entries:** Total number of races entered by the driver.
#
# **Race_Starts:** Total number of races started by the driver.
#
# **Pole_Positions:** Number of times the driver started a race from the pole position.
#
# **Race_Wins:** Total number of races won by the driver.
#
# **Podiums:** Total number of times the driver finished on the podium.
#
# **Fastest_Laps:** Number of fastest laps achieved by the driver in races.
#
# **Points:** Total points accumulated by the driver in their career.
#
# **Active:** Indicates whether the driver is currently active or not.
#
# **Championship Years:** Years in which the driver won championships.
#
# **Decade:** The decade during which the driver had the most significant success or activity.
#
# **Pole_Rate:** Percentage of races where the driver started from pole position.
#
# **Start_Rate:** Percentage of races entered in which the driver started.
#
# **Win_Rate:** Percentage of races won out of those entered.
#
# **Podium_Rate:** Percentage of races finished on the podium out of those entered.
#
# **FastLap_Rate:** Percentage of races where the driver achieved the fastest lap.
#
# **Points_Per_Entry:** Average points earned per race entry.
#
# **Years_Active:** Total years the driver has been active in the sport.
#
# **Champion:** Indicates the years or seasons in which the driver became a champion.

# %%
df.head()
# Out:
#               Driver     Nationality                         Seasons  \
# 0        Carlo Abate           Italy                    [1962, 1963]
# 1   George Abecassis  United Kingdom                    [1951, 1952]
# 2      Kenny Acheson  United Kingdom                    [1983, 1985]
# 3  Andrea de Adamich           Italy  [1968, 1970, 1971, 1972, 1973]
# 4     Philippe Adams         Belgium                          [1994]
#
#    Championships  Race_Entries  Race_Starts  Pole_Positions  Race_Wins  \
# 0              0             3            0               0          0
# 1              0             2            2               0          0
# 2             16            10            3               0          0
# 3              0            36           30               0          0
# 4              0             2            2               0          0
#
#    Podiums  Fastest_Laps  ...  Championship Years  Decade Pole_Rate  \
# ...

# %%
df.shape
# Out:
# (868, 22)

# %%
df.describe()
# Out:
#        Championships  Race_Entries  Race_Starts  Pole_Positions   Race_Wins  \
# count     868.000000    868.000000   868.000000      868.000000  868.000000
# mean        0.144009     29.917051    27.694700        1.244240    1.247696
# std         1.146178     53.780150    52.876476        6.347512    6.491921
# min         0.000000      1.000000     0.000000        0.000000    0.000000
# 25%         0.000000      2.000000     1.000000        0.000000    0.000000
# 50%         0.000000      7.000000     5.000000        0.000000    0.000000
# 75%         0.000000     29.250000    26.000000        0.000000    0.000000
# max        20.000000    359.000000   356.000000      103.000000  103.000000
#
#           Podiums  Fastest_Laps       Points       Decade   Pole_Rate  \
# count  868.000000    868.000000   868.000000   868.000000  868.000000
# mean     3.756912      1.261521    55.849459  1972.223502    0.011471
# std     14.432826      5.413644   265.968614    20.201084    0.046544
# ...

# %%
df.dtypes
# Out:
# Driver                 object
# Nationality            object
# Seasons                object
# Championships           int64
# Race_Entries            int64
# Race_Starts             int64
# Pole_Positions          int64
# Race_Wins               int64
# Podiums                 int64
# Fastest_Laps            int64
# Points                float64
# Active                   bool
# Championship Years     object
# Decade                  int64
# Pole_Rate             float64
# Start_Rate            float64
# Win_Rate              float64
# Podium_Rate           float64
# FastLap_Rate          float64
# Points_Per_Entry      float64
# Years_Active            int64
# Champion                 bool
# dtype: object

# %%
sns.set()
cols = ['Driver','Nationality','Championships','Race_Entries','Race_Wins','Points']
sns.pairplot(df[cols], height = 3.5)
plt.show();

# %%
df.isnull().sum(axis=0)
# Out:
# Driver                  0
# Nationality             0
# Seasons                 0
# Championships           0
# Race_Entries            0
# Race_Starts             0
# Pole_Positions          0
# Race_Wins               0
# Podiums                 0
# Fastest_Laps            0
# Points                  0
# Active                  0
# Championship Years    834
# Decade                  0
# Pole_Rate               0
# Start_Rate              0
# Win_Rate                0
# Podium_Rate             0
# FastLap_Rate            0
# Points_Per_Entry        0
# Years_Active            0
# Champion                0
# dtype: int64

# %%
df.drop(columns = "Decade", axis = 1)
# Out:
#                 Driver     Nationality                         Seasons  \
# 0          Carlo Abate           Italy                    [1962, 1963]
# 1     George Abecassis  United Kingdom                    [1951, 1952]
# 2        Kenny Acheson  United Kingdom                    [1983, 1985]
# 3    Andrea de Adamich           Italy  [1968, 1970, 1971, 1972, 1973]
# 4       Philippe Adams         Belgium                          [1994]
# ..                 ...             ...                             ...
# 863      Emilio Zapico           Spain                          [1976]
# 864        Zhou Guanyu           China                          [2022]
# 865      Ricardo Zonta          Brazil  [1999, 2000, 2001, 2004, 2005]
# 866        Renzo Zorzi           Italy              [1975, 1976, 1977]
# 867     Ricardo Zunino       Argentina              [1979, 1980, 1981]
#
#      Championships  Race_Entries  Race_Starts  Pole_Positions  Race_Wins  \
# ...

# %%
def heatmap(category):
    # Filter the DataFrame for only '2020s' decade
    df_2020 = df[df['Decade'] == '2020']
    
    # Pivot the data to create the heatmap structure
    heatmap_data = df_2020.pivot(index='Driver', columns='Decade', values='Points')

    plt.figure(figsize=(8, 6))  # Adjust figure size if needed

    sns.heatmap(heatmap_data, annot=True, cmap='viridis', fmt='g')

    plt.title('Points by Driver in 2020s')
    plt.xlabel('Decade')
    plt.ylabel('Driver')

    plt.show()

# %%
df = pd.read_csv("F1DriversDataset.csv")

# Filter data for Decade = 2020
df_2020 = df[df['Decade'] == 2020]

# Pivot the filtered data
pivot_df = df_2020.pivot_table(index='Driver', columns='Decade', values='Points', aggfunc='sum', fill_value=0)

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_df, cmap='viridis', annot=True, fmt='g')
plt.xlabel('Decade')
plt.ylabel('Driver')
plt.title('Points by Driver in 2020')
plt.show()
